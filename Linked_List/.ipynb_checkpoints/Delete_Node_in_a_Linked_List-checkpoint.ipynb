# %% [markdown]
# There is a singly-linked list head and we want to delete a node node in it.
#
# You are given the node to be deleted node. You will not be given access to the first node of head.
#
# All the values of the linked list are unique, and it is guaranteed that the given node node is not the last node in the linked list.
#
# Delete the given node. Note that by deleting the node, we do not mean removing it from memory. We mean:
#
# - The value of the given node should not exist in the linked list.
# - The number of nodes in the linked list should decrease by one.
# - All the values before node should be in the same order.
# - All the values after node should be in the same order.
#
# Custom testing:
#
# - For the input, you should provide the entire linked list head and the node to be given node. node should not be the last node of the list and should be an actual node in the list.
# - We will build the linked list and pass the node to your function.
# - The output will be the entire list after calling your function.

# %% [markdown]
# ## Example 1:
#
# ![image.png](attachment:image.png)
#
# __Input__: head = [4,5,1,9], node = 5
# __Output__: [4,1,9]
# __Explanation__: You are given the second node with value 5, the linked list should become 4 -> 1 -> 9 after calling your function.
#
# ## Example 2:
#
# ![image-2.png](attachment:image-2.png)
#
# __Input__: head = [4,5,1,9], node = 1
# __Output__: [4,5,9]
# __Explanation__: You are given the third node with value 1, the linked list should become 4 -> 5 -> 9 after calling your function.

# %%
def deleteNode(node):
    # Since we know input node is not last node, so nextNode will not be null
    nextNode = node.next
    # Step 2
    node.val = nextNode.val
    # Step 3
    node.next = nextNode.next
    nextNode.next = None
    del(nextNode)
    return (node)

# %%
head = [4,5,1,9]
node = 5
deleteNode(node)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wd/dds50g4912j_vc_xq4y85r_m0000gq/T/ipykernel_3503/2362595218.py in <module>
#       1 head = [4,5,1,9]
#       2 node = 5
# ----> 3 deleteNode(node)
#
# /var/folders/wd/dds50g4912j_vc_xq4y85r_m0000gq/T/ipykernel_3503/680357957.py in deleteNode(node)
#       1 def deleteNode(node):
#       2     # Since we know input node is not last node, so nextNode will not be null
# ----> 3     nextNode = node.next
#       4     # Step 2
#       5     node.val = nextNode.val
#
# AttributeError: 'int' object has no attribute 'next'
